# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("loan_approval_data.csv")
df
# Out:
#      Applicant_ID  Applicant_Income  Coapplicant_Income Employment_Status  \
# 0             1.0           17795.0              1387.0          Salaried
# 1             2.0            2860.0              2679.0          Salaried
# 2             3.0            7390.0              2106.0          Salaried
# 3             4.0           13964.0              8173.0          Salaried
# 4             5.0           13284.0              4223.0     Self-employed
# ..            ...               ...                 ...               ...
# 995         996.0               NaN              9092.0          Salaried
# 996         997.0            3279.0              6356.0     Self-employed
# 997         998.0           15192.0              8433.0          Contract
# 998         999.0            9083.0              7380.0        Unemployed
# 999        1000.0           13093.0              2385.0          Salaried
#
#       Age Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 0    51.0        Married         0.0         637.0             4.0       0.53
# 1    46.0        Married         3.0         621.0             2.0       0.30
# 2    25.0         Single         2.0         674.0             4.0       0.20
# 3    40.0        Married         2.0         579.0             3.0       0.31
# 4    31.0         Single         2.0         721.0             1.0       0.29
# ..    ...            ...         ...           ...             ...        ...
# 995  58.0        Married         0.0         557.0             0.0       0.59
# 996  58.0        Married         1.0         646.0             3.0       0.19
# 997  48.0         Single         1.0         666.0             1.0       0.40
# 998  50.0         Single         1.0         748.0             3.0       0.31
# 999  23.0        Married         1.0         613.0             3.0       0.32
#
#      Savings  Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose  \
# 0    19403.0           45638.0      16619.0       84.0     Personal
# 1     2580.0           49272.0      38687.0        NaN          Car
# 2    13844.0            6908.0      27943.0       72.0          NaN
# 3     9553.0           10844.0      27819.0       60.0     Business
# 4     9386.0           37629.0      12741.0       72.0          Car
# ..       ...               ...          ...        ...          ...
# 995   5370.0           43563.0       8311.0       72.0     Personal
# 996      NaN           18361.0      22563.0       12.0     Business
# 997   8581.0           41335.0      16203.0       24.0         Home
# 998  13491.0            8933.0      10290.0       36.0     Personal
# 999  12436.0           25816.0      35818.0       48.0     Personal
#
#     Property_Area Education_Level  Gender Employer_Category Loan_Approved
# 0           Urban    Not Graduate  Female           Private            No
# 1       Semiurban        Graduate     NaN           Private            No
# 2           Urban             NaN  Female        Government           Yes
# 3           Rural        Graduate  Female        Government            No
# 4             NaN        Graduate    Male           Private           Yes
# ..            ...             ...     ...               ...           ...
# 995           NaN    Not Graduate    Male        Unemployed            No
# 996         Urban        Graduate  Female        Government            No
# 997         Rural        Graduate    Male               MNC            No
# 998         Urban        Graduate    Male           Private           Yes
# 999     Semiurban        Graduate     NaN           Private            No
#
# [1000 rows x 20 columns]

# %%
## Data Pre-Processing and EDA

df["Employment_Status"].unique() ## 4 -> Salaried    Self-employed    Contract    Unemployed
df["Marital_Status"].unique()    ## 2 -> Married    Single
df["Loan_Purpose"].unique()      ## 5 -> Personal    Car    Business    Home    Education
df["Property_Area"].unique()     ## 3 -> Urban    Semiurban    Rural
df["Education_Level"].unique()   ## 2 -> Not Graduate    Graduate
df["Gender"].unique()            ## 2 -> Female    Male
df["Employer_Category"].unique() ## 5 -> Private    Government    Unemployed    MNC    Business
df["Loan_Approved"].unique()     ## 2 -> No    Yes
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
## Handling null values

c = ["Applicant_Income", "Coapplicant_Income", "Age", "Dependents", "Credit_Score", "Existing_Loans", "DTI_Ratio", "Savings", "Collateral_Value", "Loan_Amount", "Loan_Term"]

for col in c:
    df[col] = df[col].fillna(df[col].median())

columns = list(df.columns)
c2 = [col for col in columns if col not in c]
c2.remove('Applicant_ID')
c2.remove('Loan_Approved')

for col in c2:
    df[col] = df[col].fillna(df[col].mode()[0])

# df["Applicant_Income"] = df["Applicant_Income"].fillna(df["Applicant_Income"].median())
# df["Coapplicant_Income"] = df["Coapplicant_Income"].fillna(df["Coapplicant_Income"].median())
# df["Age"] = df["Age"].fillna(df["Age"].median())
# df["Dependents"] = df["Dependents"].fillna(df["Dependents"].median())
# df["Credit_Score"] = df["Credit_Score"].fillna(df["Credit_Score"].median())
df = df.drop(columns = ["Applicant_ID"])

# %%
df["Gender"] = df["Gender"].map({
    "Male":1,
    "Female":0
})

df["Loan_Approved"] = df["Loan_Approved"].map({
    "Yes" : 1,
    "No" : 0
})

df
# Out:
#      Applicant_Income  Coapplicant_Income Employment_Status   Age  \
# 0             17795.0              1387.0          Salaried  51.0
# 1              2860.0              2679.0          Salaried  46.0
# 2              7390.0              2106.0          Salaried  25.0
# 3             13964.0              8173.0          Salaried  40.0
# 4             13284.0              4223.0     Self-employed  31.0
# ..                ...                 ...               ...   ...
# 995           10548.0              9092.0          Salaried  58.0
# 996            3279.0              6356.0     Self-employed  58.0
# 997           15192.0              8433.0          Contract  48.0
# 998            9083.0              7380.0        Unemployed  50.0
# 999           13093.0              2385.0          Salaried  23.0
#
#     Marital_Status  Dependents  Credit_Score  Existing_Loans  DTI_Ratio  \
# 0          Married         0.0         637.0             4.0       0.53
# 1          Married         3.0         621.0             2.0       0.30
# 2           Single         2.0         674.0             4.0       0.20
# 3          Married         2.0         579.0             3.0       0.31
# 4           Single         2.0         721.0             1.0       0.29
# ..             ...         ...           ...             ...        ...
# 995        Married         0.0         557.0             0.0       0.59
# 996        Married         1.0         646.0             3.0       0.19
# 997         Single         1.0         666.0             1.0       0.40
# 998         Single         1.0         748.0             3.0       0.31
# 999        Married         1.0         613.0             3.0       0.32
#
#      Savings  Collateral_Value  Loan_Amount  Loan_Term Loan_Purpose  \
# 0    19403.0           45638.0      16619.0       84.0     Personal
# 1     2580.0           49272.0      38687.0       48.0          Car
# 2    13844.0            6908.0      27943.0       72.0     Business
# 3     9553.0           10844.0      27819.0       60.0     Business
# 4     9386.0           37629.0      12741.0       72.0          Car
# ..       ...               ...          ...        ...          ...
# 995   5370.0           43563.0       8311.0       72.0     Personal
# 996   9880.5           18361.0      22563.0       12.0     Business
# 997   8581.0           41335.0      16203.0       24.0         Home
# 998  13491.0            8933.0      10290.0       36.0     Personal
# 999  12436.0           25816.0      35818.0       48.0     Personal
#
#     Property_Area Education_Level  Gender Employer_Category  Loan_Approved
# 0           Urban    Not Graduate       0           Private            0.0
# 1       Semiurban        Graduate       1           Private            0.0
# 2           Urban        Graduate       0        Government            1.0
# 3           Rural        Graduate       0        Government            0.0
# 4           Urban        Graduate       1           Private            1.0
# ..            ...             ...     ...               ...            ...
# 995         Urban    Not Graduate       1        Unemployed            0.0
# 996         Urban        Graduate       0        Government            0.0
# 997         Rural        Graduate       1               MNC            0.0
# 998         Urban        Graduate       1           Private            1.0
# 999     Semiurban        Graduate       1           Private            0.0
#
# [1000 rows x 19 columns]

# %%
## Train Test Split

untested_data = df[df["Loan_Approved"].isna()]

data = df.dropna()

X = data.drop(columns = ["Loan_Approved"])
y = data["Loan_Approved"]

## Train Test Split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 18)

## One Hot Encoding
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(handle_unknown = "ignore")

X_train_numerical = X_train.drop(columns = c2)
X_test_numerical = X_test.drop(columns = c2)

X_train_encoded = encoder.fit_transform(X_train[c2]).toarray()
X_test_encoded = encoder.transform(X_test[c2]).toarray()

encoded_columns = encoder.get_feature_names_out(c2)



X_train_categorical = pd.DataFrame(
    X_train_encoded,
    columns = encoded_columns,
    index = X_train.index
)

X_test_categorical = pd.DataFrame(
    X_test_encoded,
    columns = encoded_columns,
    index = X_test.index
)

## Concatenation
X_train_encoded = pd.concat(
    [X_train_numerical, X_train_categorical],
    axis = 1
)

X_test_encoded = pd.concat(
    [X_test_numerical, X_test_categorical],
    axis = 1
)
# Out:
#      Applicant_Income  Coapplicant_Income   Age  Dependents  Credit_Score  \
# 809           14790.0              5699.0  32.0         2.0         601.0
# 262           10548.0              3972.0  44.0         3.0         717.0
# 843            8898.0               661.0  35.0         2.0         718.0
# 794           18984.0              9738.0  49.0         2.0         700.0
# 765            4219.0                 9.0  55.0         1.0         678.0
# ..                ...                 ...   ...         ...           ...
# 738           16309.0              2137.0  26.0         0.0         562.0
# 881            5476.0              2817.0  51.0         0.0         642.0
# 124           12173.0              4873.0  25.0         1.0         678.0
# 282           14249.0              4311.0  24.0         2.0         785.0
# 307           19532.0              2403.0  34.0         1.0         633.0
#
#      Existing_Loans  DTI_Ratio  Savings  Collateral_Value  Loan_Amount  ...  \
# 809             0.0       0.22   9880.5           41881.0      18326.0  ...
# 262             0.0       0.17  17040.0           41628.0       7060.0  ...
# 843             3.0       0.38  18044.0           43625.0      22793.0  ...
# 794             2.0       0.23   1203.0           10523.0      18131.0  ...
# 765             2.0       0.49   9880.5           34579.0      27598.0  ...
# ..              ...        ...      ...               ...          ...  ...
# 738             1.0       0.48  12929.0           24321.0      38857.0  ...
# 881             0.0       0.35  13665.0           15531.0      29204.0  ...
# 124             2.0       0.43    916.0           35497.0      21939.0  ...
# 282             4.0       0.38   2284.0           26754.0      39247.0  ...
# 307             0.0       0.25   6184.0            6683.0      23320.0  ...
#
#      Property_Area_Rural  Property_Area_Semiurban  Property_Area_Urban  \
# 809                  1.0                      0.0                  0.0
# 262                  0.0                      0.0                  1.0
# 843                  1.0                      0.0                  0.0
# 794                  1.0                      0.0                  0.0
# 765                  0.0                      1.0                  0.0
# ..                   ...                      ...                  ...
# 738                  1.0                      0.0                  0.0
# 881                  0.0                      1.0                  0.0
# 124                  0.0                      0.0                  1.0
# 282                  0.0                      0.0                  1.0
# 307                  1.0                      0.0                  0.0
#
#      Education_Level_Graduate  Education_Level_Not Graduate  \
# 809                       1.0                           0.0
# 262                       1.0                           0.0
# 843                       1.0                           0.0
# 794                       0.0                           1.0
# 765                       1.0                           0.0
# ..                        ...                           ...
# 738                       1.0                           0.0
# 881                       1.0                           0.0
# 124                       1.0                           0.0
# 282                       1.0                           0.0
# 307                       1.0                           0.0
#
#      Employer_Category_Business  Employer_Category_Government  \
# 809                         0.0                           0.0
# 262                         0.0                           1.0
# 843                         0.0                           0.0
# 794                         0.0                           0.0
# 765                         0.0                           1.0
# ..                          ...                           ...
# 738                         0.0                           1.0
# 881                         0.0                           0.0
# 124                         0.0                           0.0
# 282                         0.0                           0.0
# 307                         0.0                           0.0
#
#      Employer_Category_MNC  Employer_Category_Private  \
# 809                    0.0                        1.0
# 262                    0.0                        0.0
# 843                    0.0                        0.0
# 794                    0.0                        1.0
# 765                    0.0                        0.0
# ..                     ...                        ...
# 738                    0.0                        0.0
# 881                    1.0                        0.0
# 124                    0.0                        1.0
# 282                    1.0                        0.0
# 307                    0.0                        1.0
#
#      Employer_Category_Unemployed
# 809                           0.0
# 262                           0.0
# 843                           1.0
# 794                           0.0
# 765                           0.0
# ..                            ...
# 738                           0.0
# 881                           0.0
# 124                           0.0
# 282                           0.0
# 307                           0.0
#
# [760 rows x 33 columns]

# %%
## Scaling

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_encoded)
X_test_scaled = scaler.transform(X_test_encoded)

# %%
## Model - kNN

from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors = 19)
model.fit(X_train_scaled, y_train)

y_pred = model.predict(X_test_scaled)

# %%
## Evaluation

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy : {accuracy}    Precision : {precision}    Recall : {recall}    F1-score : {f1}")
# Out:
# Accuracy : 0.7736842105263158    Precision : 0.8571428571428571    Recall : 0.38095238095238093    F1-score : 0.5274725274725275

# %%
for k in range(1,32,2):
    model = KNeighborsClassifier(n_neighbors = k)
    model.fit(X_train_scaled, y_train)
    
    y_pred = model.predict(X_test_scaled)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    print(f"For k = {k} ->  Accuracy : {accuracy}    Precision : {precision}    Recall : {recall}    F1-score : {f1}")
# Out:
# For k = 1 ->  Accuracy : 0.7105263157894737    Precision : 0.5606060606060606    Recall : 0.5873015873015873    F1-score : 0.5736434108527132
# For k = 3 ->  Accuracy : 0.7368421052631579    Precision : 0.6226415094339622    Recall : 0.5238095238095238    F1-score : 0.5689655172413793
# For k = 5 ->  Accuracy : 0.7736842105263158    Precision : 0.6923076923076923    Recall : 0.5714285714285714    F1-score : 0.6260869565217392
# For k = 7 ->  Accuracy : 0.7736842105263158    Precision : 0.7380952380952381    Recall : 0.49206349206349204    F1-score : 0.5904761904761905
# For k = 9 ->  Accuracy : 0.7684210526315789    Precision : 0.7209302325581395    Recall : 0.49206349206349204    F1-score : 0.5849056603773585
# For k = 11 ->  Accuracy : 0.8052631578947368    Precision : 0.825    Recall : 0.5238095238095238    F1-score : 0.6407766990291263
# For k = 13 ->  Accuracy : 0.7578947368421053    Precision : 0.7428571428571429    Recall : 0.4126984126984127    F1-score : 0.5306122448979592
# For k = 15 ->  Accuracy : 0.7736842105263158    Precision : 0.8333333333333334    Recall : 0.3968253968253968    F1-score : 0.5376344086021505
# For k = 17 ->  Accuracy : 0.7842105263157895    Precision : 0.8928571428571429    Recall : 0.3968253968253968    F1-score : 0.5494505494505495
# For k = 19 ->  Accuracy : 0.7736842105263158    Precision : 0.8571428571428571    Recall : 0.38095238095238093    F1-score : 0.5274725274725275
# For k = 21 ->  Accuracy : 0.7842105263157895    Precision : 0.8666666666666667    Recall : 0.4126984126984127    F1-score : 0.5591397849462365
# For k = 23 ->  Accuracy : 0.7684210526315789    Precision : 0.8518518518518519    Recall : 0.36507936507936506    F1-score : 0.5111111111111111
# For k = 25 ->  Accuracy : 0.7684210526315789    Precision : 0.88    Recall : 0.3492063492063492    F1-score : 0.5
# For k = 27 ->  Accuracy : 0.7578947368421053    Precision : 0.8695652173913043    Recall : 0.31746031746031744    F1-score : 0.46511627906976744
# For k = 29 ->  Accuracy : 0.7473684210526316    Precision : 0.8    Recall : 0.31746031746031744    F1-score : 0.45454545454545453
# For k = 31 ->  Accuracy : 0.7578947368421053    Precision : 0.9047619047619048    Recall : 0.30158730158730157    F1-score : 0.4523809523809524

# %%
## Model - Logistic Regression

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train_scaled, y_train)

y_pred = model.predict(X_test_scaled)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"For Logistic Regression ->  Accuracy : {accuracy}    Precision : {precision}    Recall : {recall}    F1-score : {f1}")
# Out:
# For Logistic Regression ->  Accuracy : 0.8947368421052632    Precision : 0.864406779661017    Recall : 0.8095238095238095    F1-score : 0.8360655737704918
